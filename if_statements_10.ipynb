# %%
if 3 > 2:
    print("3 is greater than 2")
# Out:
# 3 is greater than 2

# %%
if 2 > 1:
    print("xyz")
# Out:
# xyz

# %%
if 1 > 2:
    print("z")  # yazdırmaz çünkü 1 2 den büyük değil

# %%
if 2 > 1:
    print("cybersecurityspecialist")
    print("Çağlar Çağatay CEYLAN")
# Out:
# cybersecurityspecialist
# Çağlar Çağatay CEYLAN

# %%
x = 2

# %%
y = 4

# %%
if x > y:
    print("x is greater")
else:
    print("y is greater")
# Out:
# y is greater

# %%
x = 4

# %%
y = 4

# %%
if x > y:
    print("x is greater")
elif x == y:
    print("x = y")
else:
    print("y is greater")
# Out:
# x = y

# %%
my_superhero = input("superhero: ")
# Out:
# superhero: deli2go

# %%
if my_superhero == "Batman":
    print("First Hero")
elif my_superhero == "Superman":
    print("Secondhero")
elif my_superhero == "Ironman":
    print("Thirdhero")
else:
    print("no hero")
# Out:
# no hero

# %%
a = 10

# %%
b = 15

# %%
c = 20

# %%
if a > b or b < c:
    print("it s one true condition")
elif a < b and b > c:
    print("second cond")
else:
    print("no cond finish")
# Out:
# it s one true condition

# %%
isCharacter_dead = False

# %%
if isCharacter_dead == False:
    print("character not dead")
else:
    print("character dead")
# Out:
# character dead

# %%
if isCharacter_dead:
    print("character is dead")
else:
    print("character is not dead")
# Out:
# character is not dead

# %%
if not isCharacter_dead:
    print("character is not dead")
# Out:
# character is not dead

# %%
my_string = "Hello World!"

# %%
if my_string == "Hello World!":
    print("it is trueeee")
# Out:
# it is trueeee

# %%
if "Hello" in my_string:
    print("true")
else:
    print("false")
# Out:
# true

# %%
my_new_list = [1, 2, 3, 5, 9]

# %%
if 8 in my_new_list:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
my_dictionary = {"k1": 100, "k2": 200, "k3": 300}

# %%
if 100 in my_dictionary.values():
    print("its ok")
else:
    print("nooo")
# Out:
# its ok

# %%
if 200 in my_dictionary.keys():
    print("yes")
else:
    print("no")
# Out:
# no
