# %%
my_list = ["a", 1, "c"]

# %%
my_list[0] = "b"

# %%
my_list
# Out:
# ['b', 1, 'c']

# %%
my_tuple = ("a", 1, "c")

# %%
my_tuple[0]
# Out:
# 'a'

# %%
my_tuple[0] = "b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8eed7cf756e9> in <module>
# ----> 1 my_tuple[0] = "b"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuple lar immutable dır.

# %%
my_tuple.count(1)
# Out:
# 1

# %%
my_tuple.count("a")
# Out:
# 1

# %%
my_tuple.index("c")
# Out:
# 2

# %%
my_tuple_2 = (1, 1, 1, "a", "e")

# %%
my_tuple_2.count(1)
# Out:
# 3

# %%
my_tuple_2.index(1)
# Out:
# 0
