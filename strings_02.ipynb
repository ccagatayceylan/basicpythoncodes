# %%
"hello world"
# Out:
# 'hello world'

# %%
'hello'
# Out:
# 'hello'

# %%
x = "hello world"

# %%
x
# Out:
# 'hello world'

# %%
len(x)
# Out:
# 11

# %%
print("hello python")
# Out:
# hello python

# %%
print("hello \npython")
# Out:
# hello
# python

# %%
print("hello \n python")
# Out:
# hello
#  python

# %%
print("hello\tppthon")
# Out:
# hello	ppthon

# %%
print("hello \tppython")
# Out:
# hello 	ppython
