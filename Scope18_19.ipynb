# %%
number = 15

def multiply(num):
    number = 5
    return num * number

# %%
multiply(10)
# Out:
# 50

# %%
print(number)
# Out:
# 15

# %%
a = 30
a = 1

# %%
print(a)
# Out:
# 1

# %%
# LEGB --->  L->Local, E->Enclosing, G->Global, B->Built in

# %%
my_string = "CyberMan" # Global

def my_func():
    my_string = "Security" # Enclosing
  

    def my_func_2():
        my_string = "Codes" # Local
        print(my_string)
    my_func_2()

# %%
my_func()
# Out:
# Codes

# %%
my_string
# Out:
# 'CyberMan'

# %%
y = 10

def func_new(y):
    print(y)

# %%
func_new(3)
# Out:
# 3

# %%
func_new(10)
# Out:
# 10

# %%
func_new(7)
# Out:
# 7

# %%
y = 10 

def func_new_2(y):
    print(y)
    y= 5
    print(y)

# %%
func_new_2(6)
# Out:
# 6
# 5

# %%
y
# Out:
# 10

# %%
func_new_2(10)
# Out:
# 10
# 5

# %%
y = 10

def func_new_2(y):
    print(y)
    y=5
    print(y)
    return(y)

# %%
y = func_new_2(y)
# Out:
# 10
# 5

# %%
y
# Out:
# 5
