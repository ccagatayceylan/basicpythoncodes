# %%
my_string = "hello world"

# %%
my_string
# Out:
# 'hello world'

# %%
my_string[0]
# Out:
# 'h'

# %%
my_string[4]
# Out:
# 'o'

# %%
my_string[-1]
# Out:
# 'd'

# %%
my_string[-2]
# Out:
# 'l'

# %%
my_string_2 = "1234567890"

# %%
my_string_2[0]
# Out:
# '1'

# %%
my_string_2[2:]
# Out:
# '34567890'

# %%
my_string_2[:2]
# Out:
# '12'

# %%
my_string_2[2:4]
# Out:
# '34'

# %%
my_string_2[::]
# Out:
# '1234567890'

# %%
my_string_2[::3]
# Out:
# '1470'

# %%
my_string_2[2:3:2]
# Out:
# '3'

# %%
my_string_2[::-1]
# Out:
# '0987654321'

# %%
my_name = "caglar"

# %%
my_name.capitalize()
# Out:
# 'Caglar'

# %%
my_name
# Out:
# 'caglar'

# %%
my_name_capitalized = my_name.capitalize()

# %%
my_name_capitalized
# Out:
# 'Caglar'

# %%
my_name = "Caglar Ceylan "

# %%
my_name.split()
# Out:
# ['Caglar', 'Ceylan']

# %%
my_name
# Out:
# 'Caglar Ceylan '

# %%
my_name_split = my_name.split()

# %%
my_name_split
# Out:
# ['Caglar', 'Ceylan']

# %%
my_name_split[0]
# Out:
# 'Caglar'

# %%
my_name.upper()
# Out:
# 'CAGLAR CEYLAN '

# %%
"james" + "5"
# Out:
# 'james5'

# %%
"james" + "tie"
# Out:
# 'jamestie'
