# %%
while True:
    try:
        my_int=int(input("Enter a number: "))
    except:
        print("You must enter a number !")
        continue
    else:
        print("OK")
        break
    finally:
        print("finally")
# Out:
# Enter a number: Jack
# You must enter a number !
# finally
# Enter a number: 11
# OK
# finally
