# %%
number =10

def multiply(num):
    number = 5
    return num * number

# %%
multiply(10)
# Out:
# 50

# %%
print(number)
# Out:
# 10

# %%
a = 10
a = 5

# %%
print(a)
# Out:
# 5

# %%
my_string = "Cagatay"

def my_func():
    my_string = "james"
    
    print(my_string)

# %%
my_func()
# Out:
# james

# %%
my_string
# Out:
# 'Cagatay'

# %%
my_string = "Cagatay"

def my_func():
    my_string = "james"

    def my_func_2():
        my_string = "Lars"
        print(my_string)
    my_func_2()

# %%
my_func()
# Out:
# Lars

# %%
my_string
# Out:
# 'Cagatay'
