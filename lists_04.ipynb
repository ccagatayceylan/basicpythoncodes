# %%
my_string = "caglar"

# %%
my_string[0] = "C"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-bbe012738097> in <module>
# ----> 1 my_string[0] = "C"
#
# TypeError: 'str' object does not support item assignment

# %%
my_list = [1, 2, 3]

# %%
my_list[0]
# Out:
# 1

# %%
my_list[0] = 5

# %%
my_list
# Out:
# [5, 2, 3]

# %%
my_list.append(7)

# %%
my_list
# Out:
# [5, 2, 3, 7]

# %%
my_list.pop()
# Out:
# 7

# %%
my_list
# Out:
# [5, 2, 3]

# %%
my_mixed_list = [1, 2, "caglar", "cyber"]

# %%
my_mixed_list[0]
# Out:
# 1

# %%
my_mixed_list[-1]
# Out:
# 'cyber'

# %%
my_list_1 = ["a", "b", "c"]

# %%
my_list_2 = ["d", "e", "f"]

# %%
my_list_3 = my_list_1 + my_list_2

# %%
my_list_3
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
my_list_1 * 3
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c']

# %%
my_list.reverse()

# %%
my_list
# Out:
# [3, 2, 5]

# %%
new_list = [1, 4, "a"]

# %%
new_list = [1, 4, "a", [3,"c"]]

# %%
new_list[3]
# Out:
# [3, 'c']

# %%
nested_list = new_list[3]

# %%
nested_list
# Out:
# [3, 'c']

# %%
nested_list[1]
# Out:
# 'c'

# %%
new_list[3][1]
# Out:
# 'c'

# %%
new_list
# Out:
# [1, 4, 'a', [3, 'c']]

# %%
new_list[2:]
# Out:
# ['a', [3, 'c']]

# %%
new_list[:2]
# Out:
# [1, 4]
