# %%
x = 6

# %%
y = 5

# %%
x > y
# Out:
# True

# %%
y > x
# Out:
# False

# %%
x < y
# Out:
# False

# %%
x >= y
# Out:
# True

# %%
 x >= 6
# Out:
# True

# %%
x >= 6.0
# Out:
# True

# %%
x >= 6.1
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
# and or not

# %%
2 > 1 and 3 > 2
# Out:
# True

# %%
2 < 1 and 3 > 2
# Out:
# False

# %%
2 < 1 or 3 > 2
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
not 10 == 10
# Out:
# False
