# %%
class Fruits():

    def __init__(self, name, calories):
        self.name = name
        self.calories = calories

    def __str__(self):
        return "example"

    def __len__(self):
        return self.calories

# %%
my_fruit = Fruits("Banana", 250)

# %%
my_fruit.calories
# Out:
# 250

# %%
print(my_fruit)
# Out:
# example

# %%
len(my_fruit)
# Out:
# 250

# %%
str(my_fruit)
# Out:
# 'example'
