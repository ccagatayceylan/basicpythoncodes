# %%
def func(new_func):
    print("func started")
    new_func()
    print("func ended")

# %%
def hello_func():
    print("hello world")

# %%
func(hello_func)
# Out:
# func started
# hello world
# func ended
