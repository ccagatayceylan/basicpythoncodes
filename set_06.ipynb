# %%
my_list = [1, 2, 3, 1]

# %%
my_list
# Out:
# [1, 2, 3, 1]

# %%
my_set = set(my_list)

# %%
my_set
# Out:
# {1, 2, 3}

# %%
my_set_2 = {1, 2, 3, 1}

# %%
my_set_2
# Out:
# {1, 2, 3}

# %%
type(my_set_2)
# Out:
# set

# %%
my_set_3 = {"a", "b", "a"}

# %%
my_set_3
# Out:
# {'a', 'b'}

# %%
my_list = []

# %%
type(my_list)
# Out:
# list

# %%
my_list
# Out:
# []

# %%
my_list.append(1)

# %%
my_list
# Out:
# [1]

# %%
my_set_4 = {}

# %%
type(my_set_4)
# Out:
# dict

# %%
my_set_5 = set()

# %%
my_set_5
# Out:
# set()

# %%
my_set_5.add(1)

# %%
my_set_5.add(2)

# %%
my_set_5
# Out:
# {1, 2}

# %%
my_set_5.add(2)

# %%
my_set_5
# Out:
# {1, 2}

# %%
type(my_set_5)
# Out:
# set

# %%
my_dict_2 = dict()

# %%
my_dict_2["key1"] = 1

# %%
my_dict_2
# Out:
# {'key1': 1}

# %%
my_list_10 = list()

# %%
type(my_list_10)
# Out:
# list

# %%
my_list_10
# Out:
# []

# %%
my_list_10.append(2)

# %%
my_list_10.append("a")

# %%
my_list_10.append([1, 2,])

# %%
my_list_10
# Out:
# [2, 'a', [1, 2]]
