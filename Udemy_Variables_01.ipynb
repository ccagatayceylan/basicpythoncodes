# %%
5+6
# Out:
# 11

# %%
900/7
# Out:
# 128.57142857142858

# %%
30 * 4
# Out:
# 120

# %%
2 * 2 * 2
# Out:
# 8

# %%
2 ** 3
# Out:
# 8

# %%
2 **9
# Out:
# 512

# %%
21 % 2
# Out:
# 1

# %%
10 % 2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
#  integer  tamsayıdır  örn 5 
#  float  ondalıklı sayıdır  örn 0.4

# %%
x  = 3

# %%
y = 5

# %%
x + y
# Out:
# 8

# %%
x**y
# Out:
# 243

# %%
r = input("r: ")
# Out:
# r: 5

# %%
type(r)
# Out:
# str

# %%
type(x)
# Out:
# int

# %%
pi = 3.14

# %%
x * pi
# Out:
# 9.42

# %%
type(pi)
# Out:
# float

# %%
r_int = int(r)

# %%
r
# Out:
# '5'

# %%
type(r_int)
# Out:
# int

# %%
r_int
# Out:
# 5
