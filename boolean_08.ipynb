# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
my_boolean = True

# %%
my_boolean
# Out:
# True

# %%
5 > 3
# Out:
# True

# %%
2 > 5
# Out:
# False

# %%
x = 6

# %%
y = input("y: ")
# Out:
# y: 3

# %%
type(y)
# Out:
# str

# %%
y_int = int(y)

# %%
y_int
# Out:
# 3

# %%
type(y_int)
# Out:
# int

# %%
y_int > 2
# Out:
# True
