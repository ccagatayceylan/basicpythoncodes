# %%
my_string = "Çağlar"

# %%
my_string.upper()
# Out:
# 'ÇAĞLAR'

# %%
my_string
# Out:
# 'Çağlar'

# %%
my_string_upper = my_string.upper()

# %%
my_string_upper
# Out:
# 'ÇAĞLAR'

# %%
help(my_string.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
def cyber_world():
    print("hello")
    print("security")

# %%
cyber_world
# Out:
# <function __main__.cyber_world()>

# %%
cyber_world()
# Out:
# hello
# security

# %%
# input & return

# %%
def hello_programming(name):
    print("hello")
    print(name)

# %%
hello_programming("Python")
# Out:
# hello
# Python

# %%
hello_programming("java")
# Out:
# hello
# java

# %%
hello_programming("codes")
# Out:
# hello
# codes

# %%
def hello_program(name="python"):
    print("Hello friends!")
    print(name)

# %%
hello_program()
# Out:
# Hello friends!
# python

# %%
hello_program("java")
# Out:
# Hello friends!
# java

# %%
def cal(number1, number2):
    number3 = number1 + number2
    print(number3)

# %%
cal(34, 45)
# Out:
# 79

# %%
cal(23, 62)
# Out:
# 85

# %%
cal(33, -40)
# Out:
# -7

# %%
def sunny (num1, num2, num3):
    return num1 + num2 + num3

# %%
sunny(10, 20, 30)
# Out:
# 60

# %%
my_num_outputs = sunny(10, 20, 30)

# %%
my_num_outputs
# Out:
# 60

# %%
def control_string(s):
    if s[0] == "m":
        print("mmm")

# %%
control_string("jump")

# %%
control_string("metal music")
# Out:
# mmm

# %%
def control_string(s):
    if s[0] =="m":
        print(s.capitalize())

# %%
control_string("Dortmund")

# %%
control_string("moldova")
# Out:
# Moldova

# %%
# arbitrary arguments & key word arguments

# %%
def summation(num1, num2):
    return num1 + num2

# %%
# *args

# %%
def summation_2(*args):
    return sum(args)

# %%
summation_2(10, 20, 30)
# Out:
# 60

# %%
def sun(*numberss):  # * a dikkat!!!
    return sum(numberss)

# %%
sun(10, 400, 456)
# Out:
# 866

# %%
def calculate(*args):
    return sum(args)

# %%
calculate(10, 45, 23, 34)
# Out:
# 112

# %%
def calculate_2(*args):
    print(args)

# %%
calculate_2("well", 1, 34)
# Out:
# ('well', 1, 34)

# %%
def example_func(**keywargs):
    print(keywargs)

# %%
example_func( run= 100, swim = 200, basketball = 300)
# Out:
# {'run': 100, 'swim': 200, 'basketball': 300}

# %%
example_func( a = 3 , b = 2)
# Out:
# {'a': 3, 'b': 2}

# %%
def example_key_word_arguments(**kwargs):
    if "Metallica" in kwargs:
        print("oh good choice")
    else:
        print("you must choice again please")

# %%
example_key_word_arguments(Metallica = 10, Rock = 20, Pop = 5)
# Out:
# oh good choice

# %%
example_key_word_arguments(pop = 34, dance = 45)
# Out:
# you must choice again please
